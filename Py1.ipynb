# %% [markdown]
# <a href="https://colab.research.google.com/github/izza1234567859/PM-4404/blob/main/Py1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello guyss")
print("test 1,2,3")
# Out:
# Hello guyss
# test 1,2,3

# %%
print("Hello, Python!")
print("Abu")
print('Hitam')
# Out:
# Hello, Python!
# Abu
# Hitam

# %%
print("nama saya \"izza aditya\"")
# Out:
# nama saya "izza aditya"

# %%
print("satu.","dua.","tiga." ,"empat.", "lima.")
# Out:
# satu. dua. tiga. empat. lima.

# %%
print("Nama saya","Izza", end=" ")
print("Salam")
# Out:
# Nama saya Izza Salam

# %%
#Clue
print("Programming","Essentials","in")
print("Python")
# Out:
# Programming Essentials in
# Python

# %%
#clue
print("    *    "*3)
print("   * *   "*3)
print("  *   *  "*3)
print(" *     * "*3)
print("***   ***"*3)
print("  *   *  "*3)
print("  *   *  "*3)
print("  *****  "*3)
# Out:
#     *        *        *
#    * *      * *      * *
#   *   *    *   *    *   *
#  *     *  *     *  *     *
# ***   ******   ******   ***
#   *   *    *   *    *   *
#   *   *    *   *    *   *
#   *****    *****    *****

# %%
print("    *\n   * *\n  *   *\n *     *\n***   ***\n  *   *\n  *   *\n  *****\n"*2)
# Out:
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****

# %%
print(5, "mempunyai tipe", type(5))
print(.5, "mempunyai tipe", type(.5))
# Out:
# 5 mempunyai tipe <class 'int'>
# 0.5 mempunyai tipe <class 'float'>

# %%
print(True)
print(False)
print(1>2)
print(7>4)
# Out:
# True
# False
# False
# True

# %%
print()

# %%
print(9 % 6 % 2)
print(9 % 6)
print(3 % 2)
print(2 ** 2 ** 3)
print(2 ** 2)
print(2 ** 8)
# Out:
# 1
# 3
# 1
# 256
# 4
# 256

# %%
5 + 5 *5
# Out:
# 30

# %%
kilometer = 12.25
mil = 7.38

# %%
miles_to_kilometers = mil * 1.61
kilometers_to_miles = kilometer / 1.61

# %%
print(mil, "1 mil adalah", round(miles_to_kilometers, 2), "kilometer")
print(kilometer, "1 kilometer adalah", round(kilometers_to_miles, 2), "mil")
# Out:
# 7.38 1 mil adalah 11.88 kilometer
# 12.25 1 kilometer adalah 7.61 mil

# %%
var = 2
var = 3
print(var)
# Out:
# 3

# %%
#test
print("Hai... aku izza")
#test1
#test2
# Out:
# Hai... aku izza

# %%
print("Katakan sesuatu...")
sesuatu = input()
print("mmmmm", sesuatu, " Oke")
# Out:
# Katakan sesuatu...

# %%
angka = float(input("Masukan Angka : "))
print("Pangkat duanya adalah ", angka**2)
